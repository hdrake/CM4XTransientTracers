# %%
# %load_ext autoreload
# %autoreload 2

# %%
import warnings
import matplotlib.pyplot as plt

# %%
import numpy as np
import glob
import xarray as xr
import xbudget
import regionate
import xwmt
import xwmb
import xgcm
import cartopy.crs as ccrs
import CM4Xutils #needed to run pip install nc-time-axis
from regionate import MaskRegions, GriddedRegion

# %% [markdown]
# ### Request HPC Resources

# %%
from dask_jobqueue import SLURMCluster  # setup dask cluster 
from dask.distributed import Client

log_directory="/vortexfs1/home/anthony.meza/scratch/CM4X/CM4XTransientTracers/WaterMassBudgets/logs"

cluster = SLURMCluster(
    cores=36,
    processes=1,
    memory='190GB',
    walltime='02:00:00',
    queue='compute',
    interface='ib0', 
log_directory = log_directory)
print(cluster.job_script())
cluster.scale(jobs=4)

client = Client(cluster)
client
# Out:
# #!/usr/bin/env bash
#
# #SBATCH -J dask-worker
# #SBATCH -e /vortexfs1/home/anthony.meza/scratch/CM4X/CM4XTransientTracers/WaterMassBudgets/logs/dask-worker-%J.err
# #SBATCH -o /vortexfs1/home/anthony.meza/scratch/CM4X/CM4XTransientTracers/WaterMassBudgets/logs/dask-worker-%J.out
# #SBATCH -p compute
# #SBATCH -n 1
# #SBATCH --cpus-per-task=36
# #SBATCH --mem=177G
# #SBATCH -t 02:00:00
#
# /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_analysis/bin/python -m distributed.cli.dask_worker tcp://172.16.3.80:36418 --name dummy-name --nthreads 36 --memory-limit 176.95GiB --nanny --death-timeout 60 --interface ib0
# <Client: 'tcp://172.16.3.80:36418' processes=0 threads=0, memory=0 B>

# %% [markdown]
# ### Load in data

# %%
import cmocean
model2glodap_names = {'cfc12':'cfc12','cfc11':'cfc11','sf6':'sf6','thetao':'theta','so':'salinity'}
variable_kwargs = {
    'cfc12':{'conversion':1e12/1035,'cmap':'Greens','units':'pmol kg-1'},
    'cfc11':{'conversion':1e12/1035,'cmap':'PuRd','units':'pmol kg-1'},
    'sf6':{'conversion':1e12/1035 * 1e3,'cmap':'Blues','units':'fmol kg-1'},
    'theta':{'conversion':1,'cmap':cmocean.cm.thermal,'units':'degK','bins':np.arange(-2,35,0.2),'anombins':np.arange(-4,4.05,0.05)},
    'thetao':{'conversion':1,'cmap':cmocean.cm.thermal,'units':'deg C','bins':np.arange(-2,35,0.2),'anombins':np.arange(-4,4.05,0.05)},
    'salinity':{'conversion':1,'cmap':cmocean.cm.haline,'units':'psu','bins':np.arange(32,37,0.05),'anombins':np.arange(-1,1.02,0.02)}
}

# %%
import glob
datadir = lambda x="" : "/vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/" + x

spinup_datafiles = sorted(glob.glob(datadir("CM4Xp125*spinup*")))
historical_datafiles = sorted(glob.glob(datadir("CM4Xp125*historical*")))
ssp585_datafiles = sorted(glob.glob(datadir("CM4Xp125_ssp585*")))
picontrol_datafiles = sorted(glob.glob(datadir("CM4Xp125*piControl*")))
picontrol_datafiles = sorted(list(set(picontrol_datafiles) - set(spinup_datafiles)))

expt_datafiles = {"forced": historical_datafiles + ssp585_datafiles, 
                  "control": picontrol_datafiles}

# %%
def column_average(ds, var): 
    return (ds["thkcello"] * ds[var]).sum("sigma2_l") / ds["thkcello"].sum("sigma2_l")

def approximate_z(ds, dim = "zl"):
    tmp = ds.thkcello.cumsum(dim = dim)
    #average between 0 and cell bottom
    tmp1 = tmp.isel({dim: 0}) / 2 
    #get top of cell
    tmp2 = tmp.isel({dim : slice(0, -1)}) 
    #get bottom of cell
    tmp3 = tmp.isel({dim : slice(1, None)}) 
    #make sure cell interfaces are on same coordinate
    tmp2.coords[dim] = tmp3.coords[dim]
    #take average
    tmp4 = (tmp2 + tmp3) / 2

    ds["z"] = xr.concat([1. * tmp1, 1. * tmp4], dim = dim)    
    ds["z_bottom"] = 1. * tmp

    ds["z"] = ds["z"].where(ds["thkcello"] > 0) 
    ds["z_bottom"] = ds["z_bottom"].where(ds["thkcello"] > 0) 

    return ds

# %%
cfc_limit_url = "https://www.pmel.noaa.gov/gobop/go-ship/cfc/atmospheric-inputs-chlorofluorocarbons"

# %%
for key in expt_datafiles.keys():
    datafiles = expt_datafiles[key]
    ds_columns = []
    ds_bottoms = []
    for (t, file) in enumerate(datafiles): 
        print(key, ":", file)
        ds = xr.open_mfdataset(
            file,
            data_vars="minimal",
            coords="minimal",
            compat="override",
            parallel=True,
            engine="zarr")
        ds['cfc11'] = (variable_kwargs['cfc11']['conversion'] * ds['cfc11'])
        ds['cfc12'] = variable_kwargs['cfc12']['conversion'] * ds['cfc12']
        ds['sf6'] = variable_kwargs['sf6']['conversion'] * ds['sf6']

        tvars = ["sf6", "cfc11", "cfc12", "so", "thetao", "agessc"]

        ds_sigma = ds.where(ds.sigma2_l >= 36.7)
        ds_column = xr.merge([column_average(ds_sigma, var).rename(var) for var in tvars]).compute()
        ds_column['cfc11'].attrs = {"units":"pmol kg-1", "detectable_limit": f"0.002 as per {cfc_limit_url}"}
        ds_column['cfc12'].attrs = {"units":"pmol kg-1", "detectable_limit": f"0.002 as per {cfc_limit_url}"}
        ds_column['sf6'].attrs = {"units":"pmol kg-1", "detectable_limit": f"0.00002 as per {cfc_limit_url}"}
        ds_column['agessc'].attrs = {"units":"years"}
        ds_columns += [1 * ds_column.compute()]

        ds_z = approximate_z(ds, dim = "sigma2_l").where(np.abs(ds["z_bottom"] - ds["deptho"]) < 250)
        ds_bottom = xr.merge([column_average(ds_z, var).rename(var) for var in tvars]).compute()
        ds_bottom['cfc11'].attrs = {"units":"pmol kg-1", "detectable_limit": f"0.002 as per {cfc_limit_url}"}
        ds_bottom['cfc12'].attrs = {"units":"pmol kg-1", "detectable_limit": f"0.002 as per {cfc_limit_url}"}
        ds_bottom['sf6'].attrs = {"units":"pmol kg-1", "detectable_limit": f"0.00002 as per {cfc_limit_url}"}
        ds_bottom['agessc'].attrs = {"units":"years"}
        ds_bottoms += [1 * ds_bottom.compute()]

    ds_columns_ts = xr.concat(ds_columns, dim = "time").sortby("time")
    ds_bottoms_ts = xr.concat(ds_bottoms, dim = "time").sortby("time")

    savedir = "/vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/"
    
    savename = savedir + f"Tracer_Columns_Sigma37_{key}.nc"
    print(f"Saving {key} to", ": ", savename)
    ds_columns_ts.to_netcdf(savename)

    savename = savedir + f"Tracer_Columns_Bottom250_{key}.nc"
    print(f"Saving {key} to", ": ", savename)
    ds_bottoms_ts.to_netcdf(savename)
# Out:
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_historical_tracers_sigma2_1850-1854.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_historical_tracers_sigma2_1855-1859.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_historical_tracers_sigma2_1860-1864.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_historical_tracers_sigma2_1865-1869.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_historical_tracers_sigma2_1870-1874.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_historical_tracers_sigma2_1875-1879.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_historical_tracers_sigma2_1880-1884.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_historical_tracers_sigma2_1885-1889.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_historical_tracers_sigma2_1890-1894.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_historical_tracers_sigma2_1895-1899.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_historical_tracers_sigma2_1900-1904.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_historical_tracers_sigma2_1905-1909.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_historical_tracers_sigma2_1910-1914.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_historical_tracers_sigma2_1915-1919.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_historical_tracers_sigma2_1920-1924.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_historical_tracers_sigma2_1925-1929.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_historical_tracers_sigma2_1930-1934.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_historical_tracers_sigma2_1935-1939.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_historical_tracers_sigma2_1940-1944.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_historical_tracers_sigma2_1945-1949.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_historical_tracers_sigma2_1950-1954.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_historical_tracers_sigma2_1955-1959.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_historical_tracers_sigma2_1960-1964.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_historical_tracers_sigma2_1965-1969.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_historical_tracers_sigma2_1970-1974.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_historical_tracers_sigma2_1975-1979.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_historical_tracers_sigma2_1980-1984.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_historical_tracers_sigma2_1985-1989.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_historical_tracers_sigma2_1990-1994.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_historical_tracers_sigma2_1995-1999.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_historical_tracers_sigma2_2000-2004.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_historical_tracers_sigma2_2005-2009.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_historical_tracers_sigma2_2010-2014.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_ssp585_tracers_sigma2_2015-2019.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_ssp585_tracers_sigma2_2020-2024.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_ssp585_tracers_sigma2_2025-2029.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_ssp585_tracers_sigma2_2030-2034.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_ssp585_tracers_sigma2_2035-2039.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_ssp585_tracers_sigma2_2040-2044.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_ssp585_tracers_sigma2_2045-2049.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_ssp585_tracers_sigma2_2050-2054.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_ssp585_tracers_sigma2_2055-2059.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_ssp585_tracers_sigma2_2060-2064.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_ssp585_tracers_sigma2_2065-2069.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_ssp585_tracers_sigma2_2070-2074.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_ssp585_tracers_sigma2_2075-2079.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_ssp585_tracers_sigma2_2080-2084.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_ssp585_tracers_sigma2_2085-2089.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_ssp585_tracers_sigma2_2090-2094.zarr
# forced : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_ssp585_tracers_sigma2_2095-2099.zarr
# Saving forced to :  /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/Tracer_Columns_Sigma37_forced.nc
# Saving forced to :  /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/Tracer_Columns_Bottom250_forced.nc
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0101-0105.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0106-0110.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0111-0115.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0116-0120.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0121-0125.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0126-0130.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0131-0135.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0136-0140.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0141-0145.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0146-0150.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0151-0155.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0156-0160.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0161-0165.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0166-0170.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0171-0175.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0176-0180.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0181-0185.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0186-0190.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0191-0195.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0196-0200.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0201-0205.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0206-0210.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0211-0215.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0216-0220.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0221-0225.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0226-0230.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0231-0235.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0236-0240.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0241-0245.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0246-0250.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0251-0255.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0256-0260.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0261-0265.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0266-0270.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0271-0275.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0276-0280.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0281-0285.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0286-0290.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0291-0295.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0296-0300.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0301-0305.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0306-0310.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0311-0315.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0316-0320.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0321-0325.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0326-0330.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0331-0335.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0336-0340.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0341-0345.zarr
# control : /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/tracers_sigma2/CM4Xp125_piControl_tracers_sigma2_0346-0350.zarr
# Saving control to :  /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/Tracer_Columns_Sigma37_control.nc
# Saving control to :  /vortexfs1/home/anthony.meza/scratch/CM4XTransientTracers/data/model/Tracer_Columns_Bottom250_control.nc
